# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.0 MB/s eta 0:00:00
# ...

# %%
cd drive/MyDrive/animal1/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/animal1/'
# /content

# %%
from ultralytics import YOLO
import cv2
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")
results = model.train(data="/content/data.yaml", epochs=50, imgsz=640, batch=8)
# Out:
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
train:images/train   # <--- Change this to the path of your training images
val: images/val    # <--- Change this to the path of your validation images

nc: 2  # <--- Change this to the number of classes in your dataset
names: ['class1', 'class2']  # <--- Change this to the actual names of your classes

# %%
# Create the data.yaml file
data_yaml_content = """
train: /content/drive/MyDrive/animal1/images/train  # Update with the actual path to your training images
val: /content/drive/MyDrive/animal1/images/val    # Update with the actual path to your validation images

nc: 2  # Update with the number of classes in your dataset
names: ['class1', 'class2']  # Update with the actual names of your classes
"""

with open('/content/sample_data/data.yaml', 'w') as f:
    f.write(data_yaml_content)

print("data.yaml created successfully in /content/sample_data/")

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.2 MB/s eta 0:00:00
# ...
